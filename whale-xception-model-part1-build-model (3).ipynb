# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import cv2
import pandas as pd
from glob import glob
import numpy as np
from matplotlib import pyplot as plt
import gc

dim = 100  # px to scale

# %% [markdown]
# Path

# %%
outside_path ='../input/happy-whale-and-dolphin/'
path = '../input/happy-whale-and-dolphin/train_images/*.jpg' 
files = glob(path)
print(os.listdir(outside_path))
print(files[:10])

# %%
train_data = pd.read_csv(outside_path+'train.csv')
samp_subm = pd.read_csv(outside_path+'sample_submission.csv')

# %%
print('Number train samples:', len(train_data))
print('Number train images:', len(os.listdir(outside_path+'train_images/')))
print('Number test images:', len(os.listdir(outside_path+'test_images/')))

# %%
train_data.head()

# %%
train_data.groupby(['species']).size().reset_index(name='counts')

# %%
### load single image

row = 0
file = train_data.loc[row, 'image']
species = train_data.loc[row, 'species']

img = cv2.imread(outside_path+'train_images/'+file)
print('Shape:', img.shape)
plt.imshow(img)

# %%
# plot multiple whales
def plot_examples(category = 'bottlenose_dolphin'):
    """ Plot 5 images of a given category """
    
    fig, axs = plt.subplots(1, 5, figsize=(25, 20))
    fig.subplots_adjust(hspace = .1, wspace=.1)
    axs = axs.ravel()
    temp = train_data[train_data['species']==category].copy()
    temp.index = range(len(temp.index))
    for i in range(5):
        file = temp.loc[i, 'image']
        species = temp.loc[i, 'species']
        img = cv2.imread(outside_path+'train_images/'+file)
        axs[i].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        axs[i].set_title(species)
        axs[i].set_xticklabels([])
        axs[i].set_yticklabels([])
    plt.show()

# %%
plot_examples(category = 'humpback_whale')

# %%
plot_examples(category = 'bottlenose_dolphin')

# %%
files[:3]

# %%
files[1].split('/')[-1]

# %%
#### ลดจำนวนรูป RAM น้อยลง 10,000 , 10,000 , 10,000 
#### image data loader maybe solution for low ram

# %%
# ### image less than 10,000 can use this method

# trainImg = []
# #try to get image label by finding picture name and going to match the csv file
# trainImg_id = []
# trainLabel = []

# j = 1
# num = len(files)

# # Obtain images and resizing, obtain labels
# for img in files:
#     print(str(j) + "/" + str(num), end="\r")
#     trainImg.append(cv2.resize(cv2.imread(img), (dim, dim)))  # Get image (with resizing)
#     #trainLabel.append(img.split('/')[-1])  # Get image label (folder name)
#     trainImg_id.append(img.split('/')[-1])  # Get image label (folder name)
#     j += 1

# trainImg = np.asarray(trainImg)  # Train images set
# #trainLabel = pd.DataFrame(trainLabel)  # Train labels set

# %%
dict_train_df = pd.read_csv('../input/happy-whale-and-dolphin/train.csv')
dict_train_df

# %%
count_species = dict_train_df.groupby(['species']).size().reset_index(name='counts')
count_species.head()

# %%
count_species['train_count'] = round(count_species['counts']*0.8)

# %%
count_species.head()

# %%
round(sum((count_species['counts'])*0.75))

# %%
dict_train_df[dict_train_df['image'] == '80b5373b87942b.jpg'].reset_index(drop=True)['species'][0]

# %%
# !pwd

# %%
# !ls

# %%
# !mkdir train
# !mkdir test

# ## ./test
# ##./train

# %%
# os.makedirs('./train')
# os.makedirs('./test')

# %%
# !pwd

# %%
from tqdm import tqdm

# %%
### LOGIC to seperate and creating files
#### loop in path ../input/happy-whale-and-dolphin/train_images
### get each file such as andjfskhfhskfhjsdjs.jpg -> check what it is as a species from csv
### if that folder of THAT species exist not create AND it THAT species not exist create one
### resize the image and put the image into folder
dim = 100
for x in tqdm(range(0,38275)):
    var_x = files[x]
    #print(var_x)
    var_x2 = files[x].split('/')[-1]
    #print(var_x2)
    
    # check image name with the dataframe
    var_species = dict_train_df[dict_train_df['image'] == var_x2].reset_index(drop=True)['species'][0]
    #print('this is ', var_species)
    
    ### check path if exist or not
    path_temp = './train/' + str(var_species)
#     if os.path.isdir(path):
#         print('this is created')
#     else:
#         print('this is not create')
#         path_to_create = path_temp
#         os.makedirs(path_to_create)
    
    # method 2 create folder name to prevent error
    try:
        #print('this is not create')
        path_to_create = path_temp
        os.makedirs(path_to_create)
    except:
          #print('this is created')
            pass
    
    ### resize image
    res_image = cv2.resize(cv2.imread(var_x), (dim, dim))
    cv2.imwrite(path_temp+'/'+var_x2, res_image)
    #trainImg.append(cv2.resize(cv2.imread(var_x), (dim, dim)))  # Get image (with resizing)
    
    
    ### put the image copy and paste into its path

# %%
#### 6950 pictures will take 10mins to run
####  13400 will take 20 mins to run (158MB)
####  38275  will take 55 mins to run (400MB)

# %%
### LOGIC to seperate and creating files range(start, stop[, step])
#### loop in path ../input/happy-whale-and-dolphin/train_images
### get each file such as andjfskhfhskfhjsdjs.jpg -> check what it is as a species from csv
### if that folder of THAT species exist not create AND it THAT species not exist create one
### resize the image and put the image into folder
dim = 100
for x in tqdm(range(38276,51033)):
    var_x = files[x]
    #print(var_x)
    var_x2 = files[x].split('/')[-1]
    #print(var_x2)
    
    # check image name with the dataframe
    var_species = dict_train_df[dict_train_df['image'] == var_x2].reset_index(drop=True)['species'][0]
    #print('this is ', var_species)
    
    ### check path if exist or not
    path_temp = './test/' + str(var_species)
#     if os.path.isdir(path):
#         print('this is created')
#     else:
#         print('this is not create')
#         path_to_create = path_temp
#         os.makedirs(path_to_create)
    
    # method 2 create folder name to prevent error
    try:
        #print('this is not create')
        path_to_create = path_temp
        os.makedirs(path_to_create)
    except:
          #print('this is created')
            pass
    
    ### resize image
    res_image = cv2.resize(cv2.imread(var_x), (dim, dim))
    cv2.imwrite(path_temp+'/'+var_x2, res_image)
    #trainImg.append(cv2.resize(cv2.imread(var_x), (dim, dim)))  # Get image (with resizing)
    
    
    ### put the image copy and paste into its path

# %%
# lst_species = []
# for x in range(len(trainImg_id)):
#     image_jpg = trainImg_id[x]
    
#     #var_species = dict_train_df[dict_train_df['image'] == image_jpg]['species']
#     var_species = dict_train_df[dict_train_df['image'] == image_jpg].reset_index(drop=True)['species'][0]
#     lst_species.append(var_species)

# %%
path2 = "./train"
dir_list = os.listdir(path2)
print(dir_list[0])
print("Files and directories in '", dir_list, "' :")

# %%
for i in range(len(dir_list)):
    path3 = "./train" + '/' + str(dir_list[i])
    #print(path3)
    dir_list1 = os.listdir(path3)
    #print(dir_list1)
    #print("Files and directories in '", dir_list1, "' :")

# %%
# datagen = ImageDataGenerator(rotation_range=20,
#                             zoom_range=0.15,
#                             width_shift_range=0.2,
#                             height_shift_range=0.2,
#                             shear_range=0.15,
#                             horizontal_flip=True,
#                             vertical_flip=True,
#                             brightness_range=[0.4,1],
#                             rescale=1.0/255.0)

# %%
### prepare folder & prepare image
# !pip install scikit-plot
from tensorflow import keras
import tensorflow as tf
from keras.utils.np_utils import to_categorical   

# Define the class name (must be corresponded to folder name of each class)
class_list = os.listdir('./train') #class name from train folder

# Normalize image function
load_func = lambda x:x/255
#Image Augmentation
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range=20,
                            zoom_range=0.15,
                            width_shift_range=0.2,
                            height_shift_range=0.2,
                            shear_range=0.15,
                            horizontal_flip=True,
                            vertical_flip=True,
                            brightness_range=[0.4,1],
                            preprocessing_function=load_func)

# Train and test folder (including sub folders for each class above)
train_path = './train'
test_path = './test'

# Image size
target_size = (100, 100)

# load and iterate training dataset
train_it = datagen.flow_from_directory(train_path, class_mode='categorical', batch_size=16,target_size=target_size,classes=class_list,shuffle=True)
#FALSE SHUFFLEEE____________________++++++++++++++++++
test_it  = datagen.flow_from_directory(test_path, class_mode='categorical', batch_size=16,target_size=target_size,classes=class_list,shuffle=False)

# %%
# ### prepare folder & prepare image
# !pip install scikit-plot
# from tensorflow import keras
# import tensorflow as tf
# from keras.utils.np_utils import to_categorical   

# # Define the class name (must be corresponded to folder name of each class)
# class_list = os.listdir('./train') #class name from train folder

# # Normalize image function
# load_func = lambda x:x/255

# datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=load_func)

# # Train and test folder (including sub folders for each class above)
# train_path = './train'
# test_path = './test'

# # Image size
# target_size = (100, 100)

# # load and iterate training dataset
# train_it = datagen.flow_from_directory(train_path, class_mode='categorical', batch_size=16,target_size=target_size,classes=class_list,shuffle=True)
# #FALSE SHUFFLEEE____________________++++++++++++++++++
# test_it  = datagen.flow_from_directory(test_path, class_mode='categorical', batch_size=16,target_size=target_size,classes=class_list,shuffle=False)

# %%
dict_datagen = train_it.class_indices
df_dict_meaning = pd.DataFrame({'class':dict_datagen.keys(), 'id':dict_datagen.values()})
df_dict_meaning.to_csv('df_dict_meaning1.csv', index=False)

# %% [markdown]
# create model

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing import image

# %%
# #### RUN ONE EPOCH to check the model size
# # model
# from tensorflow.keras import optimizers
# from tensorflow.keras.models import load_model
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten
# from keras.layers import BatchNormalization, GlobalAveragePooling2D
# from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# #from keras.applications import Xception


# num_classes = 30
# learning_rate = 0.001
# batch_size = 16

# base_model = Xception(input_shape=(dim, dim, 3), include_top=False,weights='imagenet')

# base_model.trainable = False

# model = Sequential([
#     base_model,
#     GlobalAveragePooling2D(),
#     Dense(100, activation="relu"),
#     BatchNormalization(trainable = True,axis=1),
    
#     Dropout(0.5),
    
#     Dense(50, activation="relu"),
#     BatchNormalization(trainable = True,axis=1),
    
#     Dense(num_classes,activation='softmax')
# ])


# model.compile(optimizer = optimizers.Nadam(learning_rate=learning_rate),
#               loss = 'categorical_crossentropy',
#               metrics=['accuracy'])

# # callbacks = [ EarlyStopping(monitor='val_loss', patience=5, verbose=0), 
# #               ModelCheckpoint(weights, monitor='val_loss', save_best_only=True, verbose=0),
# #               ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=0, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0)]

# result = model.fit(train_it, verbose = 1,
#                    batch_size=batch_size, epochs=25, validation_data=test_it)

# (loss, accuracy) = model.evaluate(test_it)

# print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))

# %%
# model.summary()

# %%
# ลองเปลี่ยนดู train 1 epoch

# %%
# model
from tensorflow.keras import optimizers
from tensorflow.keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import BatchNormalization, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#from keras.applications import Xception


num_classes = 30
learning_rate = 0.001
batch_size = 32

base_model = Xception(input_shape=(dim, dim, 3), include_top=False,weights='imagenet')

base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(100, activation="relu"),
    BatchNormalization(trainable = True,axis=1),
    
    Dropout(0.5),
    
    Dense(50, activation="relu"),
    BatchNormalization(trainable = True,axis=1),
    
    Dense(num_classes,activation='softmax')
])


model.compile(optimizer = optimizers.Nadam(learning_rate=learning_rate),
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

# callbacks = [ EarlyStopping(monitor='val_loss', patience=5, verbose=0), 
#               ModelCheckpoint(weights, monitor='val_loss', save_best_only=True, verbose=0),
#               ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=0, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0)]

result = model.fit(train_it, verbose = 1,
                   batch_size=batch_size, epochs=25, validation_data=test_it)

(loss, accuracy) = model.evaluate(test_it)

print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))

# %%
### epoch 10 | 0.5 | 1.2 | 0.63
### epoch 15 | 0.58 | 1.17 | 0.64
### epoch 20 | 0.59 | 1.15 | 0.65

# %%
model.summary()

# %%
### each epoch is 1000s  for  38276 trainning files
### dataset/n of batchsize = 3XXXX/16
### all the batch size should be equal

# %%
# plt.plot(result.history['accuracy'], label='train')
# plt.plot(result.history['val_accuracy'], label='valid')
# plt.legend(loc='upper left')
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.show()

# plt.plot(result.history['loss'], label='train')
# plt.plot(result.history['val_loss'], label='valid')
# plt.legend(loc='upper right')
# plt.title('Model Cost')
# plt.ylabel('Cost')
# plt.xlabel('Epoch')
# plt.show()

# %%
model.save('model_whaledophin_first_25epoch_imgaug.h5')

# %% [markdown]
# get into xception model

# %%
base_model.trainable = True
model.get_layer('xception').trainable

# %%
model.compile(optimizer=optimizers.Nadam(learning_rate=0.0006), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()

# %%
# result2 = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=50, 
#                    initial_epoch=25, validation_data=(x_valid, y_valid),verbose=1)
# result2 = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=50, 
#                    initial_epoch=25, validation_data=(x_valid, y_valid),verbose=1)
result2 = model.fit(train_it, verbose = 1,
                   batch_size=batch_size, epochs=25, validation_data=test_it)

(loss, accuracy) = model.evaluate(test_it)

print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))

# %%
model.save('model_whaledophin_first_50epoch_xception_imgaug.h5')

# %%
plt.plot(result2.history['accuracy'], label='train')
plt.plot(result2.history['val_accuracy'], label='valid')
plt.legend(loc='upper left')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(result2.history['loss'], label='train')
plt.plot(result2.history['val_loss'], label='valid')
plt.legend(loc='upper right')
plt.title('Model Cost')
plt.ylabel('Cost')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # run until this cell
# # and END

# %%
#train model
# model.fit(train_it,epochs=5, validation_data=test_it,verbose=1,workers=8)

# %%
# from keras import backend as K
# K.set_value(model.optimizer.learning_rate, 0.00003)

# %%
# model.save('model_whaledophin_first_16epoch.h5')

# %% [markdown]
# load model and develop more

# %%
# from tensorflow.keras.models import load_model

# %%
# load_model('')

# %%
# files[0]

# %%
# get list of label in the dictionary
# trainImg_id[:20]

# %%
# dict_train_df = pd.read_csv('../input/happy-whale-and-dolphin/train.csv')
# dict_train_df

# %%
# lst_species = []
# for x in range(len(trainImg_id)):
#     image_jpg = trainImg_id[x]
    
#     #var_species = dict_train_df[dict_train_df['image'] == image_jpg]['species']
#     var_species = dict_train_df[dict_train_df['image'] == image_jpg].reset_index(drop=True)['species'][0]
#     lst_species.append(var_species)

# %%
# type(lst_species[0])

# %%
# lst_species[0]

# %%
# trainLabel = pd.DataFrame(lst_species)

# %%
# trainImg_id[:4]

# %% [markdown]
# Image Preprocessing

# %%
# trainImg[0]

# %%
# import cv2

# %%
# image = cv2.imread(trainImg[0]), (dim, dim)
# plt.imshow(image)

# %%
#Creating a mask for the Green colour
#test
# blurImg = cv2.GaussianBlur(trainImg[0], (5, 5), 0)
# plt.imshow(blurImg)
# plt.show()
# # Convert to HSV image ----> can help to tell similarity between colors
# hsvImg = cv2.cvtColor(blurImg, cv2.COLOR_BGR2HSV)
# plt.imshow(hsvImg)

# %%
# def preProcessImage(Img_arr, getEx=True):
#     clearImg = []
#     for img in Img_arr:
#         # Use gaussian blur
#         blurImg = cv2.GaussianBlur(img, (5, 5), 0)   

#         # Convert to HSV image
#         hsvImg = cv2.cvtColor(blurImg, cv2.COLOR_BGR2HSV)  

#         clearImg.append(hsvImg)  # Append image without backgroung

#         # Show examples -> plot to show
#         if getEx:
#             fig = plt.figure(figsize=(10, 10))
#             imagels = [img,blurImg,hsvImg]
#             titlels = ['Original Image','Blur Image','HSV Image']
#             for i in range(3):
#                 plot = fig.add_subplot(1, 3, i + 1)
#                 plt.xticks([]),plt.yticks([])
#                 plot.title.set_text(titlels[i])
#                 plt.imshow(imagels[i])
#             plt.tight_layout()
#             plt.show()
#             getEx = False

#     return(np.asarray(clearImg))

# %%
# clearTrainImg = preProcessImage(trainImg)

# %%
# # Normalizing the train Images :   0-255 -> 0 to 1 (reduce range)
# x_train = clearTrainImg / 255.0

# %%
# # n of total class
# len(set(list(trainLabel[0])))

# %%
### 
# from sklearn.preprocessing import OneHotEncoder

# # Encode labels and create classes
# enc = OneHotEncoder(categories='auto')
# y_train = enc.fit_transform(trainLabel).toarray()

# %%
# from sklearn.model_selection import StratifiedShuffleSplit

# sss = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42) # Want a balanced split for all the classes
# for train_index, test_index in sss.split(x_train, y_train):
#     print("Using {} for training and {} for validation".format(len(train_index), len(test_index)))
#     x_train, x_valid = x_train[train_index], x_train[test_index]
#     y_train, y_valid = y_train[train_index], y_train[test_index]

# %%
# print(len(x_train))
# print(len(x_valid))
# print(len(y_train))
# print(len(y_valid))

# %%
# #Image Augmentation
# from keras.preprocessing.image import ImageDataGenerator

# datagen = ImageDataGenerator(rotation_range=20,
#                             zoom_range=0.15,
#                             width_shift_range=0.2,
#                             height_shift_range=0.2,
#                             shear_range=0.15,
#                             horizontal_flip=True,
#                             vertical_flip=True,
#                             brightness_range=[0.4,1],
#                             rescale=1.0/255.0)
# datagen.fit(x_train)

# %%
# from tensorflow.keras.applications import Xception

# %%
# from tensorflow.keras.preprocessing import image

# %%
# # model
# from tensorflow.keras import optimizers
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten
# from keras.layers import BatchNormalization, GlobalAveragePooling2D
# from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# #from keras.applications import Xception


# num_classes = 30
# learning_rate = 0.001
# batch_size = 32

# base_model = Xception(input_shape=(dim, dim, 3), include_top=False,weights='imagenet')

# base_model.trainable = False

# model = Sequential([
#     base_model,
#     GlobalAveragePooling2D(),
#     Dense(100, activation="relu"),
#     BatchNormalization(trainable = True,axis=1),
    
#     Dropout(0.5),
    
#     Dense(50, activation="relu"),
#     BatchNormalization(trainable = True,axis=1),
    
#     Dense(num_classes,activation='softmax')
# ])


# model.compile(optimizer = optimizers.Nadam(learning_rate=learning_rate),
#               loss = 'categorical_crossentropy',
#               metrics=['accuracy'])

# # callbacks = [ EarlyStopping(monitor='val_loss', patience=5, verbose=0), 
# #               ModelCheckpoint(weights, monitor='val_loss', save_best_only=True, verbose=0),
# #               ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=0, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0)]

# result = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), verbose = 1,
#                    batch_size=batch_size, epochs=25, validation_data=(x_valid, y_valid))

# (loss, accuracy) = model.evaluate(x_valid, y_valid)

# print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))

# %%
# plt.plot(result.history['accuracy'], label='train')
# plt.plot(result.history['val_accuracy'], label='valid')
# plt.legend(loc='upper left')
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.show()

# plt.plot(result.history['loss'], label='train')
# plt.plot(result.history['val_loss'], label='valid')
# plt.legend(loc='upper right')
# plt.title('Model Cost')
# plt.ylabel('Cost')
# plt.xlabel('Epoch')
# plt.show()

# %%
# #Fine-tuning our model
# base_model.trainable = True
# model.get_layer('xception').trainable

# %%
# model.compile(optimizer=optimizers.Nadam(learning_rate=0.0006), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# result = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=50, 
#                    initial_epoch=25, validation_data=(x_valid, y_valid),verbose=1)

# %%
# plt.plot(result.history['accuracy'], label='train')
# plt.plot(result.history['val_accuracy'], label='valid')
# plt.legend(loc='upper left')
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.show()

# plt.plot(result.history['loss'], label='train')
# plt.plot(result.history['val_loss'], label='valid')
# plt.legend(loc='upper right')
# plt.title('Model Cost')
# plt.ylabel('Cost')
# plt.xlabel('Epoch')
# plt.show()

# %%
# gc.collect()

# %%
# model.compile(optimizer=optimizers.Nadam(learning_rate=0.00006), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# result = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=75, 
#                    initial_epoch=50, validation_data=(x_valid, y_valid),verbose=1)

# %%
# plt.plot(result.history['accuracy'], label='train')
# plt.plot(result.history['val_accuracy'], label='valid')
# plt.legend(loc='upper left')
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.show()

# plt.plot(result.history['loss'], label='train')
# plt.plot(result.history['val_loss'], label='valid')
# plt.legend(loc='upper right')
# plt.title('Model Cost')
# plt.ylabel('Cost')
# plt.xlabel('Epoch')
# plt.show()

# %% [markdown]
# doing on test set

# %%
# ### Testing our Model on 50% 50%
# path = '../input/happy-whale-and-dolphin/test_images/*.jpg'
# files = glob(path)

# testImg = []
# testId = []
# j = 1
# num = len(files)

# # Obtain images and resizing, obtain labels
# for img in files:
#     print("Obtain images: " + str(j) + "/" + str(num), end='\r')
#     testId.append(img.split('/')[-1])  # Images id's
#     testImg.append(cv2.resize(cv2.imread(img), (dim, dim)))
#     j += 1

# testImg = np.asarray(testImg)  # Train images set

# %%
#Pre-processing the test images


# clearTestImg = preProcessImage(testImg,getEx=True)

# %%
# # Normalisation of the test images
# clearTestImg = clearTestImg / 255

# %%
# #Testing our trained Model
# pred = model.predict(clearTestImg)

# %%
#Creating the submission file


# predNum = np.argmax(pred, axis=1)
# predStr = []
# for i in range(len(predNum)):
#     predStr.append(enc.categories_[0][predNum[i]])
    
# res = {'file': testId, 'species': predStr}
# res = pd.DataFrame(res)
# res.to_csv("submission.csv", index=False)

# %%
# model.save("saved_model")

# %% [markdown]
# l

# %%
# ### RESNET

# # model
# from tensorflow.keras import optimizers
# from tensorflow.keras.models import load_model
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten
# from keras.layers import BatchNormalization, GlobalAveragePooling2D
# from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# #from keras.applications import Xception


# num_classes = 30
# learning_rate = 0.001
# batch_size = 32

# base_model = tf.keras.applications.resnet.ResNet101(
#     include_top=False, weights='imagenet'
#     input_shape=(100,100), pooling=None, classes=30
# )


# base_model.trainable = False

# model = Sequential([
#     base_model,
#     GlobalAveragePooling2D(),
#     Dense(100, activation="relu"),
#     BatchNormalization(trainable = True,axis=1),
    
#     Dropout(0.5),
    
#     Dense(50, activation="relu"),
#     BatchNormalization(trainable = True,axis=1),
    
#     Dense(num_classes,activation='softmax')
# ])


# model.compile(optimizer = optimizers.Nadam(learning_rate=learning_rate),
#               loss = 'categorical_crossentropy',
#               metrics=['accuracy'])

# # callbacks = [ EarlyStopping(monitor='val_loss', patience=5, verbose=0), 
# #               ModelCheckpoint(weights, monitor='val_loss', save_best_only=True, verbose=0),
# #               ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=0, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0)]

# result = model.fit(train_it, verbose = 1,
#                    batch_size=batch_size, epochs=25, validation_data=test_it)

# (loss, accuracy) = model.evaluate(test_it)

# print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
