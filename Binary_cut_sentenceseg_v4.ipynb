# %%
# !pip install pythainlp
# Out:
# Collecting pythainlp
#   Downloading pythainlp-3.0.5-py3-none-any.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 6.1 MB/s
# Collecting tinydb>=3.0
#   Downloading tinydb-4.6.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: typing-extensions<5.0.0,>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from tinydb>=3.0->pythainlp) (3.10.0.2)
# Installing collected packages: tinydb, pythainlp
# Successfully installed pythainlp-3.0.5 tinydb-4.6.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import InputLayer , Embedding , LSTM , TimeDistributed , Dense , Activation, Bidirectional,Concatenate, Input, Dropout
import glob
import os
from pythainlp.tokenize import word_tokenize, sent_tokenize
from pythainlp.tag import pos_tag,pos_tag_sents
from pythainlp import tag
from tqdm import tqdm
import re
import copy

# %%
st = open('/content/drive/MyDrive/SuperAI_NLP/ss_test.txt','r').read().split('\n')
st = '_'.join(st)
st = st.split('_')
max([len(i) for i in st])
# Out:
# 36

# %%
# !tar -xf /content/drive/MyDrive/SuperAI_NLP/AIFORTHAI-LST20Corpus.tar.gz

# %%
train_path = '/content/LST20_Corpus/train'
test_path = '/content/LST20_Corpus/test'

def get_doc_old(path):
  docs = []
  for i in tqdm(list(os.scandir(path))):
    if i.name[0] != '.':
      doc = open(i.path,'r').read()
      doc = doc.split('\n\n')
      doc = [[k.split('\t')[0] for k in d.split('\n')] for d in doc]
      # doc = [d.split('\t')[0] for j in doc for d in j]
      docs.append(doc)
  return docs

def get_doc(path):
  docs = []
  for i in tqdm(list(os.scandir(path))):
    if i.name[0] != '.':
      doc = open(i.path,'r').read()
      doc = doc.split('\n')
      doc = [d.split('\t')[0] if d != '' else '<SEP>' for d in doc]
      docs.append(doc[:-2])
  return docs

docs = get_doc(train_path)
docs_test = get_doc(test_path)


def get_sentence_pair_and_label(docs):
  X,Y = [],[]
  for doc in docs:
    sentence_pairs = []
    labels = []
    sen_pair = []
    label = []
    idx_to_cut = [0]*len(doc)
    # print(doc)
    for i in range(len(doc)):
      if doc[i] == '<SEP>':
        idx_to_cut[i] = 1
    
    word_seg = []
    ws = []
    for word in doc:
      if word == '<SEP>' or word == '_':
        word_seg.append(ws)
        ws = []
      else:
        ws.append(word)
    word_seg.append(ws)
    # print(word_seg)

    word_seg = [w + ['_'] for w in word_seg]

    # print(idx_to_cut)
    sum_len = 0
    size = []
    for sub in range(len(word_seg)-1):
      len_sub = len(word_seg[sub]) + sum_len - 1
      # print(len_sub)
      is_cut = idx_to_cut[len_sub]
      labels.append(is_cut)
      sentence_pairs.append([word_seg[sub], word_seg[sub+1]])
      # size.append(len(word_seg[sub]))
      # size.append(len(word_seg[sub+1]))
      sum_len += len(word_seg[sub])

    # print(sentence_pairs, labels)

    X.append(sentence_pairs)
    Y.append(labels)
  # print('max', max(size))

  return X,Y

docs_test = get_doc(test_path)
# label = get_label(docs)
# label_test = get_label(docs_test)

list_pos = ['AJ', 'AV', 'AX', 'CC', 'CL', 'FX', 'IJ', 'NG', 'NN', 'NU', 'PA', 'PR', 'PS', 'PU', 'VV', 'XX']
dic_pos = {j:i for i,j in enumerate(list_pos)}
dic_pos['<PAD_TOKEN>'] = len(dic_pos)
inv_dic_pos = {i:j for j,i in dic_pos.items()}

dic = {j:i for i,j in enumerate(list(set([x for i in get_doc_old(train_path) for d in i for x in d])))}
dic_class = {}
dic['<PAD_TOKEN>'] = len(dic)
dic['<UNKNOWN>'] = len(dic)
dic_class['I_SENT'] = len(dic_class)
dic_class['B_SENT'] = len(dic_class)
dic_class['E_SENT'] = len(dic_class)
dic_class['O_SENT'] = len(dic_class)
dic_class['P_SENT'] = len(dic_class)
inv_dic_class = {i:j for j,i in dic_class.items()}

sentence_pairs, labels = get_sentence_pair_and_label(docs)
sentence_pairs_test, labels_test = get_sentence_pair_and_label(docs_test)

max_len = 50
def preprocess_sentence(x):
  # print(x)
  output = []
  x = [[i, dic_pos[pos_tag([i], corpus='lst20')[0][1]]] for i in x]
  # print(x)
  x = [[dic[i[0]] if i[0] in dic.keys() else dic['<UNKNOWN>'], i[1]] for i in x]
  # print(x)
  if len(x) > max_len: return -1
  x =  x + [[dic['<PAD_TOKEN>'], dic_pos['<PAD_TOKEN>']]]*(max_len - len(x))
  return x

def gen_data(sentence_pairs, labels):
  X_train = []
  Y_train = []
  for sentence_pair,label in tqdm(zip(sentence_pairs, labels), total=len(sentence_pairs)):
    temp = []
    temp_l = []
    s2_copy = None
    for (s1,s2) ,lab in zip(sentence_pair, label):
      s1 = s2_copy if s2_copy is not None else preprocess_sentence(s1)
      s2 = preprocess_sentence(s2)
      s2_copy = copy.deepcopy(s2)
      if s1 == -1 or s2 == -1: continue
      temp.append([s1,s2])
      temp_l.append(lab)
    X_train.append(temp)
    Y_train.append(temp_l)
  return X_train, Y_train

X_train, Y_train  = gen_data(sentence_pairs, labels)
X_test, Y_test  = gen_data(sentence_pairs_test, labels_test)
# Out:
# 100%|██████████| 7588/7588 [00:01<00:00, 3887.10it/s]
# 100%|██████████| 966/966 [00:00<00:00, 5998.47it/s]
# 100%|██████████| 966/966 [00:00<00:00, 4840.62it/s]
# 100%|██████████| 7588/7588 [00:02<00:00, 3741.63it/s]
# 100%|██████████| 3794/3794 [01:57<00:00, 32.42it/s]
# 100%|██████████| 483/483 [00:08<00:00, 55.34it/s]

# %%
sentence_pairs[0]
# Out:
# [[['อดีต', 'ส.ส.', 'อีสาน', 'ปชป.', '"', 'ไขก๊อก', '"', '_'],
#   ['"', 'ยุทธพงศ์', '"', 'อ้าง', 'ทบทวน', 'ตัวเอง', '_']],
#  [['"', 'ยุทธพงศ์', '"', 'อ้าง', 'ทบทวน', 'ตัวเอง', '_'],
#   ['"', 'ยุทธพงศ์', '_']],
#  [['"', 'ยุทธพงศ์', '_'], ['จรัสเสถียร', '"', '_']],
#  [['จรัสเสถียร', '"', '_'], ['มือปราบ', 'รถ', 'ดับ', 'เพลิง', '_']],
#  [['มือปราบ', 'รถ', 'ดับ', 'เพลิง', '_'], ['อดีต', '_']],
#  [['อดีต', '_'], ['ส.ส.', 'มหาสารคาม', '_']],
#  [['ส.ส.', 'มหาสารคาม', '_'], ['ยื่น', 'ใบ', 'ลาออก', 'จาก', '_']],
#  [['ยื่น', 'ใบ', 'ลาออก', 'จาก', '_'], ['ปชป.', '_']],
#  [['ปชป.', '_'], ['หลัง', 'อยู่', 'ใต้', 'ร่มเงา', 'นาน', '_']],
#  [['หลัง', 'อยู่', 'ใต้', 'ร่มเงา', 'นาน', '_'], ['10', '_']],
#  [['10', '_'], ['ปี', '_']],
#  [['ปี', '_'], ['อ้าง', 'ขอ', 'เวลา', 'ทบทวน', 'ตัวเอง', 'สัก', 'ระยะ', '_']],
#  [['อ้าง', 'ขอ', 'เวลา', 'ทบทวน', 'ตัวเอง', 'สัก', 'ระยะ', '_'],
#   ['ปัด', 'ยัง', 'ไม่', 'คิด', 'ไป', 'สังกัด', 'พรรค', 'อื่น', '_']],
#  [['ปัด', 'ยัง', 'ไม่', 'คิด', 'ไป', 'สังกัด', 'พรรค', 'อื่น', '_'],
#   ['นาย', 'ยุทธพงศ์', '_']],
#  [['นาย', 'ยุทธพงศ์', '_'], ['จรัสเสถียร', '_']],
#  [['จรัสเสถียร', '_'], ['อดีต', '_']],
#  [['อดีต', '_'], ['ส.ส.', 'มหาสารคาม', '_']],
#  [['ส.ส.', 'มหาสารคาม', '_'], ['พรรค', 'ประชาธิปัตย์', 'เปิดเผย', 'ว่า', '_']],
#  [['พรรค', 'ประชาธิปัตย์', 'เปิดเผย', 'ว่า', '_'],
#   ['เมื่อ', 'เช้า', 'วันที่', '_']],
#  [['เมื่อ', 'เช้า', 'วันที่', '_'], ['13', '_']],
#  [['13', '_'], ['กรกฎาคม', 'ที่', 'ผ่าน', 'มา', '_']],
#  [['กรกฎาคม', 'ที่', 'ผ่าน', 'มา', '_'],
#   ['ได้',
#    'ยื่น',
#    'หนังสือ',
#    'ลาออก',
#    'จาก',
#    'การ',
#    'เป็น',
#    'สมาชิก',
#    'พรรค',
#    'ประชาธิปัตย์',
#    'เป็น',
#    'ทางการ',
#    'แล้ว',
#    '_']],
#  [['ได้',
#    'ยื่น',
#    'หนังสือ',
#    'ลาออก',
#    'จาก',
#    'การ',
#    'เป็น',
#    'สมาชิก',
#    'พรรค',
#    'ประชาธิปัตย์',
#    'เป็น',
#    'ทางการ',
#    'แล้ว',
#    '_'],
#   ['ถือ',
#    'ว่า',
#    'มี',
#    'ผล',
#    'โดย',
#    'สมบูรณ์',
#    'นับ',
#    'ตั้งแต่',
#    'วัน',
#    'นี้',
#    'เป็นต้นไป',
#    '_']],
#  [['ถือ',
#    'ว่า',
#    'มี',
#    'ผล',
#    'โดย',
#    'สมบูรณ์',
#    'นับ',
#    'ตั้งแต่',
#    'วัน',
#    'นี้',
#    'เป็นต้นไป',
#    '_'],
#   ['"', 'ต้อง', 'ขอบคุณ', 'พรรค', '_']],
#  [['"', 'ต้อง', 'ขอบคุณ', 'พรรค', '_'], ['ประชาธิปัตย์', '_']],
#  [['ประชาธิปัตย์', '_'], ['ที่', 'ทำให้', 'ผม', 'ได้', 'เกิด', '_']],
#  [['ที่', 'ทำให้', 'ผม', 'ได้', 'เกิด', '_'], ['เติบโต', '_']],
#  [['เติบโต', '_'],
#   ['และ', 'ทำงาน', 'ทาง', 'การเมือง', 'มา', 'ตลอด', 'ระยะ', '_']],
#  [['และ', 'ทำงาน', 'ทาง', 'การเมือง', 'มา', 'ตลอด', 'ระยะ', '_'], ['10', '_']],
#  [['10', '_'], ['ปี', 'เต็ม', '_']],
#  [['ปี', 'เต็ม', '_'], ['เนื่องจาก', 'วัน', 'นี้', '_']],
#  [['เนื่องจาก', 'วัน', 'นี้', '_'],
#   ['ไม่', 'ได้', 'มี', 'สถานะ', 'ของ', 'ความ', 'เป็น', '_']],
#  [['ไม่', 'ได้', 'มี', 'สถานะ', 'ของ', 'ความ', 'เป็น', '_'], ['ส.ส.', '_']],
#  [['ส.ส.', '_'], ['อีก', 'ทั้ง', 'เห็น', 'ว่า', '_']],
#  [['อีก', 'ทั้ง', 'เห็น', 'ว่า', '_'],
#   ['พรรค',
#    'ประชาธิปัตย์',
#    'จน',
#    'ได้',
#    'กลับ',
#    'มา',
#    'เป็น',
#    'รัฐบาล',
#    'อีก',
#    'ครั้ง',
#    '_']],
#  [['พรรค',
#    'ประชาธิปัตย์',
#    'จน',
#    'ได้',
#    'กลับ',
#    'มา',
#    'เป็น',
#    'รัฐบาล',
#    'อีก',
#    'ครั้ง',
#    '_'],
#   ['จึง', 'ตัดสินใจ', 'ลาออก', '_']],
#  [['จึง', 'ตัดสินใจ', 'ลาออก', '_'],
#   ['โดย', 'ไม่', 'ได้', 'มี', 'ความ', 'โกรธเคือง', '_']],
#  [['โดย', 'ไม่', 'ได้', 'มี', 'ความ', 'โกรธเคือง', '_'],
#   ['หรือ', 'น้อยเนื้อต่ำใจ', 'ใด', 'ๆ', '_']],
#  [['หรือ', 'น้อยเนื้อต่ำใจ', 'ใด', 'ๆ', '_'],
#   ['เพียง',
#    'แค่',
#    'ต้องการ',
#    'กลับ',
#    'ไป',
#    'นั่ง',
#    'คิด',
#    'และ',
#    'ทบทวน',
#    'เกี่ยวกับ',
#    'อนาคต',
#    'ทาง',
#    'การเมือง',
#    'สัก',
#    'ระยะ',
#    '"',
#    '_']],
#  [['เพียง',
#    'แค่',
#    'ต้องการ',
#    'กลับ',
#    'ไป',
#    'นั่ง',
#    'คิด',
#    'และ',
#    'ทบทวน',
#    'เกี่ยวกับ',
#    'อนาคต',
#    'ทาง',
#    'การเมือง',
#    'สัก',
#    'ระยะ',
#    '"',
#    '_'],
#   ['นาย', 'ยุทธพงศ์', 'กล่าว', '_']],
#  [['นาย', 'ยุทธพงศ์', 'กล่าว', '_'], ['ผู้สื่อข่าว', 'ถาม', 'ว่า', '_']],
#  [['ผู้สื่อข่าว', 'ถาม', 'ว่า', '_'],
#   ['มีการ', 'ปรึกษา', 'ใคร', 'ก่อน', 'ที่', 'จะ', 'ตัดสินใจ', 'หรือไม่', '_']],
#  [['มีการ', 'ปรึกษา', 'ใคร', 'ก่อน', 'ที่', 'จะ', 'ตัดสินใจ', 'หรือไม่', '_'],
#   ['นาย', 'ยุทธพงศ์', 'กล่าว', 'ว่า', '_']],
#  [['นาย', 'ยุทธพงศ์', 'กล่าว', 'ว่า', '_'],
#   ['"', 'ยอมรับ', 'ว่า', 'ไม่', 'ได้', 'ปรึกษา', 'ใคร', '_']],
#  [['"', 'ยอมรับ', 'ว่า', 'ไม่', 'ได้', 'ปรึกษา', 'ใคร', '_'],
#   ['เป็น', 'การ', 'ตัดสินใจ', 'ด้วย', 'ตัวเอง', '_']],
#  [['เป็น', 'การ', 'ตัดสินใจ', 'ด้วย', 'ตัวเอง', '_'],
#   ['ต้อง', 'ขอโทษ', 'ผู้', 'ใหญ่', 'หลาย', 'ๆ', '_']],
#  [['ต้อง', 'ขอโทษ', 'ผู้', 'ใหญ่', 'หลาย', 'ๆ', '_'],
#   ['คน', 'ที่', 'ให้', 'โอกาส', '"', '_']],
#  [['คน', 'ที่', 'ให้', 'โอกาส', '"', '_'], ['เมื่อ', 'ถาม', 'ว่า', '_']],
#  [['เมื่อ', 'ถาม', 'ว่า', '_'],
#   ['เป็น',
#    'เพราะ',
#    'ขุดคุ้ย',
#    'โครงการ',
#    'ทุจริต',
#    'การ',
#    'จัดซื้อ',
#    'เรือ',
#    'ดับ',
#    'เพลิง',
#    'ของ',
#    'กรุงเทพ',
#    '_']],
#  [['เป็น',
#    'เพราะ',
#    'ขุดคุ้ย',
#    'โครงการ',
#    'ทุจริต',
#    'การ',
#    'จัดซื้อ',
#    'เรือ',
#    'ดับ',
#    'เพลิง',
#    'ของ',
#    'กรุงเทพ',
#    '_'],
#   ['มหานคร', '_']],
#  [['มหานคร', '_'], ['(', 'กทม.', ')', '_']],
#  [['(', 'กทม.', ')', '_'], ['มูลค่า', 'กว่า', '_']],
#  [['มูลค่า', 'กว่า', '_'], ['6,700', '_']],
#  [['6,700', '_'], ['ล้าน', 'บาท', '_']],
#  [['ล้าน', 'บาท', '_'],
#   ['จน',
#    'ทำให้',
#    'เกิด',
#    'ปัญหา',
#    'กับ',
#    'แกนนำ',
#    'พรรค',
#    'ประชาธิปัตย์',
#    'คน',
#    'หรือไม่',
#    '_']],
#  [['จน',
#    'ทำให้',
#    'เกิด',
#    'ปัญหา',
#    'กับ',
#    'แกนนำ',
#    'พรรค',
#    'ประชาธิปัตย์',
#    'คน',
#    'หรือไม่',
#    '_'],
#   ['นาย', 'ยุทธพงศ์', 'กล่าว', 'ว่า', '_']],
#  [['นาย', 'ยุทธพงศ์', 'กล่าว', 'ว่า', '_'],
#   ['"', 'ไม่', 'เกี่ยว', 'กัน', '_']],
#  [['"', 'ไม่', 'เกี่ยว', 'กัน', '_'],
#   ['การ',
#    'ดำเนินการ',
#    'เรื่อง',
#    'ดังกล่าว',
#    'ถือ',
#    'เป็น',
#    'การ',
#    'ทำ',
#    'หน้าที่',
#    'ของ',
#    'ประชาชน',
#    '_']],
#  [['การ',
#    'ดำเนินการ',
#    'เรื่อง',
#    'ดังกล่าว',
#    'ถือ',
#    'เป็น',
#    'การ',
#    'ทำ',
#    'หน้าที่',
#    'ของ',
#    'ประชาชน',
#    '_'],
#   ['คน', 'หนึ่ง', '_']],
#  [['คน', 'หนึ่ง', '_'],
#   ['ที่',
#    'เห็น',
#    'ความ',
#    'ไม่',
#    'ชอบมาพากล',
#    'จาก',
#    'โครงการ',
#    'ดังกล่าว',
#    '"',
#    '_']],
#  [['ที่',
#    'เห็น',
#    'ความ',
#    'ไม่',
#    'ชอบมาพากล',
#    'จาก',
#    'โครงการ',
#    'ดังกล่าว',
#    '"',
#    '_'],
#   ['ถาม', 'ว่า', '_']],
#  [['ถาม', 'ว่า', '_'],
#   ['ใน', 'การ', 'เลือกตั้ง', 'ครั้ง', 'หน้า', 'จะ', 'ลง', 'สมัคร', '_']],
#  [['ใน', 'การ', 'เลือกตั้ง', 'ครั้ง', 'หน้า', 'จะ', 'ลง', 'สมัคร', '_'],
#   ['ส.ส.', 'อีก', 'หรือไม่', '_']],
#  [['ส.ส.', 'อีก', 'หรือไม่', '_'],
#   ['และ', 'ลง', 'ใน', 'นาม', 'พรรค', 'การเมือง', 'ใด', '_']],
#  [['และ', 'ลง', 'ใน', 'นาม', 'พรรค', 'การเมือง', 'ใด', '_'],
#   ['นาย', 'ยุทธพงศ์', 'กล่าว', 'ว่า', '_']],
#  [['นาย', 'ยุทธพงศ์', 'กล่าว', 'ว่า', '_'],
#   ['"',
#    'ตอน',
#    'นี้',
#    'ยัง',
#    'ไม่',
#    'คิด',
#    'สมัคร',
#    'เข้า',
#    'พรรค',
#    'การเมือง',
#    'ใด',
#    '_']],
#  [['"',
#    'ตอน',
#    'นี้',
#    'ยัง',
#    'ไม่',
#    'คิด',
#    'สมัคร',
#    'เข้า',
#    'พรรค',
#    'การเมือง',
#    'ใด',
#    '_'],
#   ['เพราะ',
#    'ต้องการ',
#    'กลับ',
#    'มา',
#    'ทบทวน',
#    'และ',
#    'ปรับปรุง',
#    'บทบาท',
#    'ทาง',
#    'การเมือง',
#    '_']],
#  [['เพราะ',
#    'ต้องการ',
#    'กลับ',
#    'มา',
#    'ทบทวน',
#    'และ',
#    'ปรับปรุง',
#    'บทบาท',
#    'ทาง',
#    'การเมือง',
#    '_'],
#   ['เนื่องจาก', 'ทำงาน', 'การเมือง', 'มา', 'นาน', 'ถึง', 'สิบ', 'ปี', '_']],
#  [['เนื่องจาก', 'ทำงาน', 'การเมือง', 'มา', 'นาน', 'ถึง', 'สิบ', 'ปี', '_'],
#   ['และ', 'ช่วง', 'เวลา', 'ที่', 'เหลือ', 'นับ', 'จาก', 'นี้', '_']],
#  [['และ', 'ช่วง', 'เวลา', 'ที่', 'เหลือ', 'นับ', 'จาก', 'นี้', '_'],
#   ['จะ', 'ทำ', 'ธุรกิจ', 'ส่วน', 'ตัว', '_']],
#  [['จะ', 'ทำ', 'ธุรกิจ', 'ส่วน', 'ตัว', '_'],
#   ['ดูแล', 'กิจการ', 'ของ', 'ครอบครัว', '"', '_']],
#  [['ดูแล', 'กิจการ', 'ของ', 'ครอบครัว', '"', '_'], ['อนึ่ง', '_']],
#  [['อนึ่ง', '_'],
#   ['นาย', 'ยุทธพงศ์', 'เป็น', 'สมาชิก', 'พรรค', 'ประชาธิปัตย์', 'ปี', '_']],
#  [['นาย', 'ยุทธพงศ์', 'เป็น', 'สมาชิก', 'พรรค', 'ประชาธิปัตย์', 'ปี', '_'],
#   ['2543', '_']],
#  [['2543', '_'], ['ได้รับการ', 'เลือกตั้ง', 'เป็น', '_']],
#  [['ได้รับการ', 'เลือกตั้ง', 'เป็น', '_'], ['ส.ส.', '_']],
#  [['ส.ส.', '_'], ['เมื่อ', 'ปี', '_']],
#  [['เมื่อ', 'ปี', '_'], ['2544', '_']],
#  [['2544', '_'],
#   ['มี',
#    'บทบาท',
#    'การเมือง',
#    'ใน',
#    'ฐานะ',
#    'ผู้',
#    'เปิดโปง',
#    'โครงการ',
#    'จัดซื้อ',
#    'รถ',
#    'ดับ',
#    'เพลิง',
#    'และ',
#    'เรือ',
#    'ดับ',
#    'เพลิง',
#    'ของ',
#    '_']],
#  [['มี',
#    'บทบาท',
#    'การเมือง',
#    'ใน',
#    'ฐานะ',
#    'ผู้',
#    'เปิดโปง',
#    'โครงการ',
#    'จัดซื้อ',
#    'รถ',
#    'ดับ',
#    'เพลิง',
#    'และ',
#    'เรือ',
#    'ดับ',
#    'เพลิง',
#    'ของ',
#    '_'],
#   ['กทม.', '_']],
#  [['กทม.', '_'], ['ที่', 'ไม่', 'โปร่งใส', '_']],
#  [['ที่', 'ไม่', 'โปร่งใส', '_'],
#   ['อีก',
#    'ทั้ง',
#    'ยัง',
#    'เคย',
#    'เป็น',
#    'กรรมการ',
#    'บริหาร',
#    'พรรค',
#    'ประชาธิปัตย์',
#    '_']],
#  [['อีก',
#    'ทั้ง',
#    'ยัง',
#    'เคย',
#    'เป็น',
#    'กรรมการ',
#    'บริหาร',
#    'พรรค',
#    'ประชาธิปัตย์',
#    '_'],
#   ['2', '_']],
#  [['2', '_'], ['สมัย', '_']],
#  [['สมัย', '_'], ['เมื่อ', 'ปี', '_']],
#  [['เมื่อ', 'ปี', '_'], ['2547', ',', '2548', '_']],
#  [['2547', ',', '2548', '_'],
#   ['เป็น',
#    'รอง',
#    'โฆษก',
#    'พรรค',
#    'ประชาธิปัตย์',
#    'และ',
#    'ผู้',
#    'ช่วย',
#    'เลขาธิการ',
#    'พรรค',
#    'ประชาธิปัตย์',
#    '_']]]

# %%
docs[0]
# Out:
# ['อดีต',
#  'ส.ส.',
#  'อีสาน',
#  'ปชป.',
#  '"',
#  'ไขก๊อก',
#  '"',
#  '_',
#  '"',
#  'ยุทธพงศ์',
#  '"',
#  'อ้าง',
#  'ทบทวน',
#  'ตัวเอง',
#  '<SEP>',
#  '"',
#  'ยุทธพงศ์',
#  '_',
#  'จรัสเสถียร',
#  '"',
#  '_',
#  'มือปราบ',
#  'รถ',
#  'ดับ',
#  'เพลิง',
#  '_',
#  'อดีต',
#  '_',
#  'ส.ส.',
#  'มหาสารคาม',
#  '_',
#  'ยื่น',
#  'ใบ',
#  'ลาออก',
#  'จาก',
#  '_',
#  'ปชป.',
#  '_',
#  'หลัง',
#  'อยู่',
#  'ใต้',
#  'ร่มเงา',
#  'นาน',
#  '_',
#  '10',
#  '_',
#  'ปี',
#  '_',
#  'อ้าง',
#  'ขอ',
#  'เวลา',
#  'ทบทวน',
#  'ตัวเอง',
#  'สัก',
#  'ระยะ',
#  '_',
#  'ปัด',
#  'ยัง',
#  'ไม่',
#  'คิด',
#  'ไป',
#  'สังกัด',
#  'พรรค',
#  'อื่น',
#  '<SEP>',
#  'นาย',
#  'ยุทธพงศ์',
#  '_',
#  'จรัสเสถียร',
#  '_',
#  'อดีต',
#  '_',
#  'ส.ส.',
#  'มหาสารคาม',
#  '_',
#  'พรรค',
#  'ประชาธิปัตย์',
#  'เปิดเผย',
#  'ว่า',
#  '_',
#  'เมื่อ',
#  'เช้า',
#  'วันที่',
#  '_',
#  '13',
#  '_',
#  'กรกฎาคม',
#  'ที่',
#  'ผ่าน',
#  'มา',
#  '_',
#  'ได้',
#  'ยื่น',
#  'หนังสือ',
#  'ลาออก',
#  'จาก',
#  'การ',
#  'เป็น',
#  'สมาชิก',
#  'พรรค',
#  'ประชาธิปัตย์',
#  'เป็น',
#  'ทางการ',
#  'แล้ว',
#  '_',
#  'ถือ',
#  'ว่า',
#  'มี',
#  'ผล',
#  'โดย',
#  'สมบูรณ์',
#  'นับ',
#  'ตั้งแต่',
#  'วัน',
#  'นี้',
#  'เป็นต้นไป',
#  '<SEP>',
#  '"',
#  'ต้อง',
#  'ขอบคุณ',
#  'พรรค',
#  '_',
#  'ประชาธิปัตย์',
#  '_',
#  'ที่',
#  'ทำให้',
#  'ผม',
#  'ได้',
#  'เกิด',
#  '_',
#  'เติบโต',
#  '_',
#  'และ',
#  'ทำงาน',
#  'ทาง',
#  'การเมือง',
#  'มา',
#  'ตลอด',
#  'ระยะ',
#  '_',
#  '10',
#  '_',
#  'ปี',
#  'เต็ม',
#  '_',
#  'เนื่องจาก',
#  'วัน',
#  'นี้',
#  '_',
#  'ไม่',
#  'ได้',
#  'มี',
#  'สถานะ',
#  'ของ',
#  'ความ',
#  'เป็น',
#  '_',
#  'ส.ส.',
#  '_',
#  'อีก',
#  'ทั้ง',
#  'เห็น',
#  'ว่า',
#  '_',
#  'พรรค',
#  'ประชาธิปัตย์',
#  'จน',
#  'ได้',
#  'กลับ',
#  'มา',
#  'เป็น',
#  'รัฐบาล',
#  'อีก',
#  'ครั้ง',
#  '_',
#  'จึง',
#  'ตัดสินใจ',
#  'ลาออก',
#  '_',
#  'โดย',
#  'ไม่',
#  'ได้',
#  'มี',
#  'ความ',
#  'โกรธเคือง',
#  '_',
#  'หรือ',
#  'น้อยเนื้อต่ำใจ',
#  'ใด',
#  'ๆ',
#  '_',
#  'เพียง',
#  'แค่',
#  'ต้องการ',
#  'กลับ',
#  'ไป',
#  'นั่ง',
#  'คิด',
#  'และ',
#  'ทบทวน',
#  'เกี่ยวกับ',
#  'อนาคต',
#  'ทาง',
#  'การเมือง',
#  'สัก',
#  'ระยะ',
#  '"',
#  '_',
#  'นาย',
#  'ยุทธพงศ์',
#  'กล่าว',
#  '<SEP>',
#  'ผู้สื่อข่าว',
#  'ถาม',
#  'ว่า',
#  '_',
#  'มีการ',
#  'ปรึกษา',
#  'ใคร',
#  'ก่อน',
#  'ที่',
#  'จะ',
#  'ตัดสินใจ',
#  'หรือไม่',
#  '<SEP>',
#  'นาย',
#  'ยุทธพงศ์',
#  'กล่าว',
#  'ว่า',
#  '_',
#  '"',
#  'ยอมรับ',
#  'ว่า',
#  'ไม่',
#  'ได้',
#  'ปรึกษา',
#  'ใคร',
#  '_',
#  'เป็น',
#  'การ',
#  'ตัดสินใจ',
#  'ด้วย',
#  'ตัวเอง',
#  '_',
#  'ต้อง',
#  'ขอโทษ',
#  'ผู้',
#  'ใหญ่',
#  'หลาย',
#  'ๆ',
#  '_',
#  'คน',
#  'ที่',
#  'ให้',
#  'โอกาส',
#  '"',
#  '<SEP>',
#  'เมื่อ',
#  'ถาม',
#  'ว่า',
#  '_',
#  'เป็น',
#  'เพราะ',
#  'ขุดคุ้ย',
#  'โครงการ',
#  'ทุจริต',
#  'การ',
#  'จัดซื้อ',
#  'เรือ',
#  'ดับ',
#  'เพลิง',
#  'ของ',
#  'กรุงเทพ',
#  '_',
#  'มหานคร',
#  '_',
#  '(',
#  'กทม.',
#  ')',
#  '_',
#  'มูลค่า',
#  'กว่า',
#  '_',
#  '6,700',
#  '_',
#  'ล้าน',
#  'บาท',
#  '_',
#  'จน',
#  'ทำให้',
#  'เกิด',
#  'ปัญหา',
#  'กับ',
#  'แกนนำ',
#  'พรรค',
#  'ประชาธิปัตย์',
#  'คน',
#  'หรือไม่',
#  '<SEP>',
#  'นาย',
#  'ยุทธพงศ์',
#  'กล่าว',
#  'ว่า',
#  '_',
#  '"',
#  'ไม่',
#  'เกี่ยว',
#  'กัน',
#  '_',
#  'การ',
#  'ดำเนินการ',
#  'เรื่อง',
#  'ดังกล่าว',
#  'ถือ',
#  'เป็น',
#  'การ',
#  'ทำ',
#  'หน้าที่',
#  'ของ',
#  'ประชาชน',
#  '_',
#  'คน',
#  'หนึ่ง',
#  '_',
#  'ที่',
#  'เห็น',
#  'ความ',
#  'ไม่',
#  'ชอบมาพากล',
#  'จาก',
#  'โครงการ',
#  'ดังกล่าว',
#  '"',
#  '<SEP>',
#  'ถาม',
#  'ว่า',
#  '_',
#  'ใน',
#  'การ',
#  'เลือกตั้ง',
#  'ครั้ง',
#  'หน้า',
#  'จะ',
#  'ลง',
#  'สมัคร',
#  '_',
#  'ส.ส.',
#  'อีก',
#  'หรือไม่',
#  '_',
#  'และ',
#  'ลง',
#  'ใน',
#  'นาม',
#  'พรรค',
#  'การเมือง',
#  'ใด',
#  '<SEP>',
#  'นาย',
#  'ยุทธพงศ์',
#  'กล่าว',
#  'ว่า',
#  '_',
#  '"',
#  'ตอน',
#  'นี้',
#  'ยัง',
#  'ไม่',
#  'คิด',
#  'สมัคร',
#  'เข้า',
#  'พรรค',
#  'การเมือง',
#  'ใด',
#  '_',
#  'เพราะ',
#  'ต้องการ',
#  'กลับ',
#  'มา',
#  'ทบทวน',
#  'และ',
#  'ปรับปรุง',
#  'บทบาท',
#  'ทาง',
#  'การเมือง',
#  '_',
#  'เนื่องจาก',
#  'ทำงาน',
#  'การเมือง',
#  'มา',
#  'นาน',
#  'ถึง',
#  'สิบ',
#  'ปี',
#  '_',
#  'และ',
#  'ช่วง',
#  'เวลา',
#  'ที่',
#  'เหลือ',
#  'นับ',
#  'จาก',
#  'นี้',
#  '_',
#  'จะ',
#  'ทำ',
#  'ธุรกิจ',
#  'ส่วน',
#  'ตัว',
#  '_',
#  'ดูแล',
#  'กิจการ',
#  'ของ',
#  'ครอบครัว',
#  '"',
#  '<SEP>',
#  'อนึ่ง',
#  '_',
#  'นาย',
#  'ยุทธพงศ์',
#  'เป็น',
#  'สมาชิก',
#  'พรรค',
#  'ประชาธิปัตย์',
#  'ปี',
#  '_',
#  '2543',
#  '_',
#  'ได้รับการ',
#  'เลือกตั้ง',
#  'เป็น',
#  '_',
#  'ส.ส.',
#  '_',
#  'เมื่อ',
#  'ปี',
#  '_',
#  '2544',
#  '_',
#  'มี',
#  'บทบาท',
#  'การเมือง',
#  'ใน',
#  'ฐานะ',
#  'ผู้',
#  'เปิดโปง',
#  'โครงการ',
#  'จัดซื้อ',
#  'รถ',
#  'ดับ',
#  'เพลิง',
#  'และ',
#  'เรือ',
#  'ดับ',
#  'เพลิง',
#  'ของ',
#  '_',
#  'กทม.',
#  '_',
#  'ที่',
#  'ไม่',
#  'โปร่งใส',
#  '<SEP>',
#  'อีก',
#  'ทั้ง',
#  'ยัง',
#  'เคย',
#  'เป็น',
#  'กรรมการ',
#  'บริหาร',
#  'พรรค',
#  'ประชาธิปัตย์',
#  '_',
#  '2',
#  '_',
#  'สมัย',
#  '_',
#  'เมื่อ',
#  'ปี',
#  '_',
#  '2547',
#  ',',
#  '2548',
#  '_',
#  'เป็น',
#  'รอง',
#  'โฆษก',
#  'พรรค',
#  'ประชาธิปัตย์',
#  'และ',
#  'ผู้',
#  'ช่วย',
#  'เลขาธิการ',
#  'พรรค',
#  'ประชาธิปัตย์']

# %%
# X_train_2 = []
merged_X_train = []
merged_Y_train = []
merged_X_test = []
merged_Y_test = []
for i,j in zip(X_train,Y_train):
  merged_X_train.extend(i)
  merged_Y_train.extend(j)

for i,j in zip(X_test,Y_test):
  merged_X_test.extend(i)
  merged_Y_test.extend(j)
    # print(np.array(j))
  # print(np.array(i).shape)

# %%
len([j for i in Y_train for j in i])
# Out:
# 461192

# %%
merged_X_train = np.array(merged_X_train)
merged_Y_train = np.array(merged_Y_train)
merged_X_test = np.array(merged_X_test)
merged_Y_test = np.array(merged_Y_test)

# %%
print(merged_X_train.shape, merged_Y_train.shape)
print(merged_X_test.shape, merged_Y_test.shape)
# Out:
# (461192, 2, 50, 2) (461192,)
# (37955, 2, 50, 2) (37955,)

# %%
import random
perm = [[p1,p2] for p1,p2 in zip(np.random.permutation(len(merged_X_train)),np.random.permutation(len(merged_X_train)))]
augmented_X_train = []
augmented_Y_train = []
for p1,p2 in tqdm(perm):
  if p1 == p2: continue
  dat1 = merged_X_train[p1]
  dat2 = merged_X_train[p2]
  sen1 = dat1[0,:,:]
  sen2 = dat2[1,:,:]
  sen3 = dat1[1,:,:]
  sen4 = dat2[0,:,:]
  aug1 = np.array([sen1,sen2])
  aug2 = np.array([sen3,sen4])
  augmented_X_train.extend([aug1, aug2])
  augmented_Y_train.extend([0,0])
# Out:
# 100%|██████████| 461192/461192 [00:04<00:00, 99430.74it/s]

# %%
augmented_X_train = np.array(augmented_X_train)
augmented_Y_train = np.array(augmented_Y_train)
merged_X_train = np.concatenate((merged_X_train, augmented_X_train), axis = 0)
merged_Y_train = np.concatenate((merged_Y_train, augmented_Y_train), axis = 0)

# %%
# model = Sequential() 
# model.add(InputLayer(input_shape=(1024,)))
# model.add(Embedding(len(dic),64))
# model.add(Bidirectional(LSTM(64,return_sequences=True)))
# model.add(TimeDistributed(Dense(5)))
# model.add(Activation('softmax'))
# model.compile(optimizer="Adam",loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               weighted_metrics=['accuracy'], run_eagerly=True)

input_word = Input(shape=(50,))
embed_word = Embedding(len(dic),64)(input_word)
input_pos = Input(shape=(50,))
embed_pos = Embedding(len(dic_pos),10)(input_pos)
input_word2 = Input(shape=(50,))
embed_word2 = Embedding(len(dic),64)(input_word2)
input_pos2 = Input(shape=(50,))
embed_pos2 = Embedding(len(dic_pos),10)(input_pos2)

concat = Concatenate()([embed_word, embed_pos, embed_word2, embed_pos2])
bidirec = Bidirectional(LSTM(80,return_sequences=False))(concat)
time_dis = Dense(30)(bidirec)
drop = Dropout(0.3)(time_dis)
dense = Dense(13)(drop)
dense = Dense(1)(dense)
act = Activation('sigmoid')(dense)
model = Model(inputs=[input_word, input_pos, input_word2, input_pos2], outputs=[act])
model.compile(optimizer="Adam",loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'], run_eagerly=True)

# input_word = Input(shape=(1024,))
# embed_word = Embedding(len(dic),64)(input_word)
# input_pos = Input(shape=(1024,))
# embed_pos = Embedding(len(dic_pos),4)(input_pos)

# concat = Concatenate()([embed_word, embed_pos])
# bidirec = Bidirectional(LSTM(128,return_sequences=True))(concat)
# bidirec = Bidirectional(LSTM(64,return_sequences=True))(bidirec)
# bidirec = Bidirectional(LSTM(32,return_sequences=True))(bidirec)
# time_dis = TimeDistributed(Dense(5))(bidirec)
# act = Activation('softmax')(time_dis)
# model = Model(inputs=[input_word, input_pos], outputs=[act])
# model.compile(optimizer="Adam",loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               weighted_metrics=['accuracy'], run_eagerly=True)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50)]         0           []
#
#  input_2 (InputLayer)           [(None, 50)]         0           []
#
#  input_3 (InputLayer)           [(None, 50)]         0           []
#
#  input_4 (InputLayer)           [(None, 50)]         0           []
#
#  embedding (Embedding)          (None, 50, 64)       3132672     ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 50, 10)       170         ['input_2[0][0]']
#
#  embedding_2 (Embedding)        (None, 50, 64)       3132672     ['input_3[0][0]']
#
#  embedding_3 (Embedding)        (None, 50, 10)       170         ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 50, 148)      0           ['embedding[0][0]',
#                                                                   'embedding_1[0][0]',
#                                                                   'embedding_2[0][0]',
#                                                                   'embedding_3[0][0]']
#
#  bidirectional (Bidirectional)  (None, 160)          146560      ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 30)           4830        ['bidirectional[0][0]']
#
#  dropout (Dropout)              (None, 30)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 13)           403         ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 1)            14          ['dense_1[0][0]']
#
#  activation (Activation)        (None, 1)            0           ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 6,417,491
# Trainable params: 6,417,491
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class_weight = {0: 1.1,
                1: 15.0,
                }
class_weight
# Out:
# {0: 1.1, 1: 15.0}

# %%
def gen_sample_weight(Y, class_weight):
  Y = copy.deepcopy(np.array(Y).astype(np.float32))
  for k,v in class_weight.items():
    Y[Y==k] = v
  return Y

sample_weight = gen_sample_weight(merged_Y_train, class_weight)

# %%
sample_weight
# Out:
# array([ 1.1, 15. ,  1.1, ...,  1.1,  1.1,  1.1], dtype=float32)

# %%
sample_weight[sample_weight == 1.0]
# Out:
# array([], dtype=float32)

# %%
model.fit(
    [merged_X_train[:,0,:,0],
     merged_X_train[:,0,:,1],
     merged_X_train[:,1,:,0],
     merged_X_train[:,1,:,1]], 
    merged_Y_train, 
    batch_size = 300, 
    validation_data = ( 
      [merged_X_test[:,0,:,0],
     merged_X_test[:,0,:,1],
     merged_X_test[:,1,:,0],
     merged_X_test[:,1,:,1]], merged_Y_test),
    sample_weight = gen_sample_weight(merged_Y_train, class_weight), 
    epochs=20)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 4612/4612 [==============================] - 327s 70ms/step - loss: 0.7302 - accuracy: 0.8434 - val_loss: 0.2943 - val_accuracy: 0.8704
# Epoch 2/20
# 4612/4612 [==============================] - 320s 69ms/step - loss: 0.5952 - accuracy: 0.8606 - val_loss: 0.3044 - val_accuracy: 0.8573
# Epoch 3/20
#  287/4612 [>.............................] - ETA: 4:57 - loss: 0.4883 - accuracy: 0.8859
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-6d1c0402f797> in <module>()
#      12      merged_X_test[:,1,:,1]], merged_Y_test),
#      13     sample_weight = gen_sample_weight(merged_Y_train, class_weight),
# ---> 14     epochs=20)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in train_function(iterator)
#    1019       def train_function(iterator):
#    1020         """Runs a training execution with a single step."""
# -> 1021         return step_function(self, iterator)
#    1022
#    1023       if not self.run_eagerly:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in step_function(model, iterator)
#    1008             run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009       data = next(iterator)
# -> 1010       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011       outputs = reduce_per_replica(
#    1012           outputs, self.distribute_strategy, reduction='first')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1310       fn = autograph.tf_convert(
#    1311           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1313
#    1314   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2886       kwargs = {}
#    2887     with self._container_strategy().scope():
# -> 2888       return self._call_for_each_replica(fn, args, kwargs)
#    2889
#    2890   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3687   def _call_for_each_replica(self, fn, args, kwargs):
#    3688     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689       return fn(*args, **kwargs)
#    3690
#    3691   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     593   def wrapper(*args, **kwargs):
#     594     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595       return func(*args, **kwargs)
#     596
#     597   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in run_step(data)
#     998
#     999       def run_step(data):
# -> 1000         outputs = model.train_step(data)
#    1001         # Ensure counter is updated only if `train_step` succeeds.
#    1002         with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in train_step(self, data)
#     857     # Run forward pass.
#     858     with tf.GradientTape() as tape:
# --> 859       y_pred = self(x, training=True)
#     860       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     861     self._validate_target_and_loss(y, loss)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     450     """
#     451     return self._run_internal_graph(
# --> 452         inputs, training=training, mask=mask)
#     453
#     454   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     587
#     588         args, kwargs = node.map_arguments(tensor_dict)
# --> 589         outputs = node.layer(*args, **kwargs)
#     590
#     591         # Update tensor_dict.
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     588
#     589     if initial_state is None and constants is None:
# --> 590       return super(Bidirectional, self).__call__(inputs, **kwargs)
#     591
#     592     # Applies the same workaround as in `RNN.__call__`
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py in call(self, inputs, training, mask, initial_state, constants)
#     706                              initial_state=forward_state, **kwargs)
#     707       y_rev = self.backward_layer(backward_inputs,
# --> 708                                   initial_state=backward_state, **kwargs)
#     709     else:
#     710       y = self.forward_layer(inputs, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     677
#     678     if initial_state is None and constants is None:
# --> 679       return super(RNN, self).__call__(inputs, **kwargs)
#     680
#     681     # If any of `initial_state` or `constants` are specified and are Keras
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1247           if can_use_gpu:
#    1248             last_output, outputs, new_h, new_c, runtime = gpu_lstm(
# -> 1249                 **gpu_lstm_kwargs)
#    1250           else:
#    1251             last_output, outputs, new_h, new_c, runtime = standard_lstm(
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in gpu_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths)
#    1467       biases=tf.split(full_bias, 8),
#    1468       shape=tf.constant([-1]),
# -> 1469       transpose_weights=True)
#    1470
#    1471   if sequence_lengths is not None:
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in _canonical_to_params(weights, biases, shape, transpose_weights)
#    1304     return tf.transpose(w) if transpose_weights else w
#    1305
# -> 1306   weights = [tf.reshape(convert(x), shape) for x in weights]
#    1307   biases = [tf.reshape(x, shape) for x in biases]
#    1308   return tf.concat(weights + biases, axis=0)
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in <listcomp>(.0)
#    1304     return tf.transpose(w) if transpose_weights else w
#    1305
# -> 1306   weights = [tf.reshape(convert(x), shape) for x in weights]
#    1307   biases = [tf.reshape(x, shape) for x in biases]
#    1308   return tf.concat(weights + biases, axis=0)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in reshape(tensor, shape, name)
#     193   """
#     194   result = gen_array_ops.reshape(tensor, shape, name)
# --> 195   tensor_util.maybe_set_static_shape(result, shape)
#     196   return result
#     197
#
# KeyboardInterrupt:

# %%
merged_X_train[:,0,:,0]
# Out:
# array([[33838,  7361, 22217, ..., 48946, 48946, 48946],
#        [38072, 19040, 48946, ..., 48946, 48946, 48946],
#        [20063, 19040, 48946, ..., 48946, 48946, 48946],
#        ...,
#        [ 4357, 23543, 44581, ..., 48946, 48946, 48946],
#        [31821, 19040, 48946, ..., 48946, 48946, 48946],
#        [12616, 19040, 48946, ..., 48946, 48946, 48946]])

# %%
y_pred = model.predict([merged_X_test[:,0,:,0],
     merged_X_test[:,0,:,1],
     merged_X_test[:,1,:,0],
     merged_X_test[:,1,:,1]])

# %%
model.save('/content/drive/MyDrive/SuperAI_NLP/binary_cut_1p5m_85f1.h5')

# %%
correct = 0
total = np.sum(np.array(Y_test) == dic_class['O_SENT'])
corr = 0
for yp,yt in zip(y_pred, Y_test):
  pred = [inv_dic_class[d] for d in np.argmax(yp, axis=1).tolist()]
  gt = [inv_dic_class[d] for d in yt]

  for p,g in zip(pred, gt):
    if g == 'O_SENT':
      if p == g: corr += 1
      # print(p,g)
  # break

print('ac', corr/total)
# Out:
# ac 0.7570367474589523

# %%
import pandas as pd

my_file =  open('/content/drive/MyDrive/SuperAI_NLP/ss_test.txt', 'r')


r = my_file.read()


data = r.split("\n")
# print(data)
my_file.close()
text = ''
for  i in range(len(data)):
    
    if data[i] =='':
        text = text+' '
        data[i] = '_'
    else:
        text = text+data[i]
# print(text)
# print(data)
df = pd.DataFrame({'word':data})
data = np.array(data)
id = np.where(data == '_')[0]

# %%
data = '<separator>'.join(data).split('<separator>')

temp_data = []
t = []
for i in data:
  if i != '_': t.append(i)
  else: temp_data.append(t); t = []
if len(t) != 0: temp_data.append(t); t=[] 

data = temp_data
sent_pair = []
for i in range(len(data)-1):
  if data[i].__len__() == 0: break
  sent1 = data[i]
  sent2 = data[i+1]
  if len(sent2) == 0: continue
  # if sent1[0] == '' and len(sent1) > 1: sent1 = sent1[1:]
  # if sent2[0] == '' and len(sent2) > 1: sent2 = sent2[1:]
  sent1 = sent1[:] + ['_']
  sent2 = sent2[:] + ['_']
  pos1 = [dic_pos[pos_tag([k], corpus='lst20')[0][1]] for k in sent1]
  pos2 = [dic_pos[pos_tag([k], corpus='lst20')[0][1]] for k in sent2]
  sent1 = [dic[d] if d in dic.keys() else dic['<UNKNOWN>'] for d in sent1]
  sent2 = [dic[d] if d in dic.keys() else dic['<UNKNOWN>'] for d in sent2]
  pos1 = pos1 + [dic_pos['<PAD_TOKEN>']]*(50 - len(pos1))
  pos2 = pos2 + [dic_pos['<PAD_TOKEN>']]*(50 - len(pos2))
  sent1 = sent1 + [dic['<PAD_TOKEN>']]*(50 - len(sent1))
  sent2 = sent2 + [dic['<PAD_TOKEN>']]*(50 - len(sent2))
  merg1 = [[d,p] for d,p in zip(sent1,pos1)]
  merg2 = [[d,p] for d,p in zip(sent2,pos2)]
  sent_pair.append([merg1,merg2])
# data = [[d, pos_tag([i], corpus='lst20')[0][1]] for d in data]
  # prdint(pred)
  # index = np.sort(id[(id > inc) & (id < 1024 + inc)])[-1]
  # inc = i
  # print(index)
sent_pair = np.array(sent_pair)

# %%
data[i]
# Out:
# ['2/2004']

# %%
data[-3]
# Out:
# ['หนังสือพิมพ์', 'ผู้', 'จัด', 'การ']

# %%
sent_pair[11]
# Out:
# array([[[11414,     8],
#         [30003,     8],
#         [36247,     8],
#         [31124,     8],
#         [21452,     9],
#         [ 4532,    12],
#         [  911,     8],
#         [27797,     8],
#         [38130,     8],
#         [12227,     3],
#         [32948,     8],
#         [ 3709,    14],
#         [ 3711,    12],
#         [ 9210,     8],
#         [27797,     8],
#         [40095,    13],
#         [22949,    13],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16]],
#
#        [[28742,    14],
#         [48179,     5],
#         [22378,    14],
#         [27537,    14],
#         [ 9094,    14],
#         [15961,     8],
#         [22949,    13],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16],
#         [48946,    16]]])

# %%
out = np.round(model.predict(
   [sent_pair[:,0,:,0],
     sent_pair[:,0,:,1],
     sent_pair[:,1,:,0],
     sent_pair[:,1,:,1]]
))

# %%
group_output = []
for d,o in zip(data, out):
  group_output.append([d,o])

# %%
out_result = []
lab = []

flag = True
for i in group_output:
  # i[0] = ''i[0].strip(' ')
  if flag : lab.append('B_SENT'); flag=False
  else: lab.append('I_SENT')
  # i[0] = i[0].split(' ')
  out_result.append(i[0][0])
  # if len(i[0]) > 1:
  for j in i[0][1:]:
    lab.append('I_SENT')
    out_result.append(j)
  if i[1][0] == 1.:
    out_result.append('_')
    lab[-1] = 'E_SENT'
    lab.append('O')
    flag = True
  else: 
    out_result.append('_')
    # lab[-1] = 'I_SENT'
    lab.append('I_SENT')

# %%
t = []
for i,j,l in zip(out_result, data,lab):
  t.append([i,j,l])

# %%
lab.append('I_SENT')

# %%
sub['Predicted'] = lab

# %%
data[::-1][:100]
# Out:
# array(['_', '_', '2/2004', '_', 'การ', 'จัด', 'ผู้', 'หนังสือพิมพ์', '_',
#        'ใหม่', 'อุบัติ', 'โรค', 'ควบคุม', 'การ', 'ถึง', 'ไป', 'รวม', '_',
#        'เร็ว', 'ได้', 'โรค', 'ของ', 'ระบาด', 'การ', 'ควบคุม', 'และ',
#        'ดูแล', 'ช่วย', 'จะ', '_', 'ได้', 'ศูนย์', '_', '12', '_', 'ทั้ง',
#        'ภูมิภาค', 'ใน', 'แล็บ', 'ศูนย์', 'ของ', 'เข้มแข็ง', 'ความ',
#        'พัฒนา', 'สามารถ', 'ถ้า', 'ซึ่ง', '_', 'ยาว', 'คิว', 'วิเคราะห์',
#        'ตรวจ', 'การ', 'ที่', 'ขณะ', '_', 'กรุงเทพฯ', 'ใน', 'เฉพาะ',
#        'เข้มแข็ง', 'ศูนย์', 'มี', 'เหมือน', 'นี้', 'ขณะ', 'เพราะ', '_',
#        'เขต', 'ศูนย์', 'ใน', '_', 'จังหวัด', 'ต่าง', 'เขต', 'ใน', 'แล็บ',
#        'ศักยภาพ', 'พัฒนา', 'การ', 'เรื่อง', 'พิจารณา', 'กำลัง', 'ยาว',
#        'ระยะ', 'แต่', '_', 'แล้ว', 'หนึ่ง', 'ส่วน', 'ไว้', 'ขอ', 'นี้',
#        'ขณะ', 'นั้น', 'ประมาณ', 'งบ', 'เรื่อง', '_', 'ว่า', 'กล่าว'],
#       dtype='<U36')

# %%
sub.to_csv('submitz.csv',index=False)

# %%
data[:100]
# Out:
# array(['กล่าว', 'ชม', 'ตร.', 'เร่ง', 'สำนวน', 'คดี', 'เร็ว', 'ดี', 'ลั่น',
#        'จะ', 'ไม่', 'หนี', 'เหมือน', 'นัก', 'การ', 'เมือง', 'บาง', 'คน',
#        '_', 'ตาม', 'ที่', 'นาย', 'ธนชาติ', '_', 'แสงประดับธรรมโชติ', '_',
#        'เข้า', 'แจ้ง', 'ความ', 'กับ', '_', 'ตำรวจ', '_', 'สน.',
#        'นางเลิ้ง', 'เมื่อ', '_', '29', '_', 'มิ.ย.', '_', '2551', '_',
#        'โดย', 'กล่าวหา', 'นาย', 'สมเกียรติ', '_', 'พงษ์ไพบูลย์', '_',
#        'ส.ส.', 'สัดส่วน', 'พรรค', 'ประชาธิปัตย์', 'หนึ่ง', 'ใน', 'แกนนำ',
#        'พันธมิตร', 'ประชาชน', 'เพื่อ', 'ประชาธิปไตย', 'ปราศรัย', 'บน',
#        'เวที', 'พันธมิตร', 'ฯ', '_', 'มี', 'การ', 'กล่าว', 'พาดพิง',
#        'ดูหมิ่น', 'สถาบัน', '_', 'มี', 'ความ', 'ผิด', 'ตาม', 'ประมวล',
#        'กฎหมาย', 'อาญา', '_', 'มาตรา', '_', '112', '_', 'โดย', 'นำ',
#        'เทป', 'การ', 'กล่าว', 'ปราศรัย', '_', 'ภาพ', 'ถ่าย', '_', 'ภาพ',
#        'วีดีโอ', '_', 'มอบ'], dtype='<U36')

# %%
for i in data:
  print(len(i.split(' ')))

# %%
print(res.__len__())
print(data.__len__())
# Out:
# 74405
# 74405

# %%
map_class = {
    'B_SENT':'B_SENT',
    'I_SENT':'I_SENT',
    'E_SENT':'E_SENT',
    'O_SENT':'O',
    'P_SENT':'I_SENT',
}

res = [map_class[i] for i in res]

# %%
np.unique(res, return_counts=True)
# Out:
# (array(['B_SENT', 'E_SENT', 'I_SENT', 'O'], dtype='<U6'),
#  array([ 1196,  1240, 70745,  1224]))

# %%
sub = pd.read_csv('/content/drive/MyDrive/SuperAI_NLP/ss_sample_submission.csv')
# sub['Predicted'] = res[:-2]

# %%
sub.to_csv('submit3.csv',index=False)

# %%
sub
# Out:
#           Id Predicted
# 0          1    I_SENT
# 1          2    I_SENT
# 2          3    I_SENT
# 3          4    I_SENT
# 4          5    I_SENT
# ...      ...       ...
# 74398  74399    I_SENT
# 74399  74400    I_SENT
# 74400  74401    I_SENT
# 74401  74402    I_SENT
# 74402  74403    I_SENT
#
# [74403 rows x 2 columns]
# Warning: total number of rows (74403) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
rez = y_pred.argmax(2).flatten()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-275-31ea873abae4> in <module>()
# ----> 1 rez = y_pred.argmax(2).flatten()
#
# AxisError: axis 2 is out of bounds for array of dimension 2

# %%
import copy
temp_rez = []
t = []
count = 0
for i in rez:
  if i == 'O':
    count += 1
    if len(t) == 0:print('t')
    temp_rez.append(copy.deepcopy(t))
    t = []
  else:
    count += 1
    t.append(i)
temp_rez.append(t)
# rez = ''.join(rez).split('O')
rez = [['I_SENT']*len(i) for i in temp_rez]
for i in range(len(rez)):
  if len(rez[i]) == 0: 
    rez[i] = ['I_SENT']
    continue
  elif len(rez[i]) == 1: rez[i] = ['B_SENT']
  elif len(rez[i]) == 2: rez[i] = ['B_SENT','E_SENT']
  else:
    rez[i][0] = 'B_SENT'
    rez[i][-1] = 'E_SENT'
  rez[i].append('O')

temp = []
for i in rez:
  for j in i:
    temp.append(j)
  # temp.append('O')
# rez = [i for j in rez for i in j]
temp = [dic_class[i] for i in temp]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-61dcd6951bee> in <module>()
#      32   # temp.append('O')
#      33 # rez = [i for j in rez for i in j]
# ---> 34 temp = [dic_class[i] for i in temp]
#
# <ipython-input-31-61dcd6951bee> in <listcomp>(.0)
#      32   # temp.append('O')
#      33 # rez = [i for j in rez for i in j]
# ---> 34 temp = [dic_class[i] for i in temp]
#
# KeyError: 'O'

# %%
from sklearn.metrics import f1_score

ytest = np.array(Y_test).flatten()
ypred = temp[:-1]

f1_score(ytest, ypred, average='micro')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-274-8ffeed075e17> in <module>()
#       2
#       3 ytest = np.array(Y_test).flatten()
# ----> 4 ypred = temp[:-1]
#       5
#       6 f1_score(ytest, ypred, average='micro')
#
# NameError: name 'temp' is not defined

# %%
from sklearn.metrics import f1_score

ytest = np.array(Y_test).flatten()
ypred = y_pred.argmax(2).flatten()

f1_score(ytest, ypred, average='micro')
# Out:
# 0.9683412977867203

# %%
from sklearn.metrics import f1_score

ytest = np.array(Y_test).flatten()
ypred = y_pred.argmax(2).flatten()

f1_score(ytest, ypred, average='micro')
# Out:
# 0.9763286751760564

# %%
from sklearn.metrics import f1_score

ytest = np.array(merged_Y_test).flatten()
ypred = np.round(y_pred[:,0]).astype(np.uint8)

f1_score(ytest, ypred, average='micro')
# Out:
# 0.8566460281912791

# %%
y_pred
# Out:
# array([[4.6172515e-02],
#        [2.1210741e-05],
#        [6.9497329e-01],
#        ...,
#        [2.3458363e-02],
#        [2.7394648e-08],
#        [5.7124515e-13]], dtype=float32)

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/SuperAI_NLP/model_0999_bilstm_1.h5')

# %%
pos_tag(docs[0][0],corpus='lst20')
# Out:
# [('เปิด', 'VV'),
#  ('ขนส่ง', 'VV'),
#  ('สินค้า', 'NN'),
#  ('เชื่อม', 'VV'),
#  (' ', 'PU'),
#  ('3', 'NU'),
#  (' ', 'PU'),
#  ('ประเทศ', 'CL')]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-c0b9781def5c> in <module>()
# ----> 1 pos_tag_sents(docs[0],corpus='orchid_ud')
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/pos_tag.py in pos_tag_sents(sentences, engine, corpus)
#     167         return []
#     168
# --> 169     return [pos_tag(sent, engine=engine, corpus=corpus) for sent in sentences]
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/pos_tag.py in <listcomp>(.0)
#     167         return []
#     168
# --> 169     return [pos_tag(sent, engine=engine, corpus=corpus) for sent in sentences]
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/pos_tag.py in pos_tag(words, engine, corpus)
#     114         )
#     115
# --> 116     word_tags = tag_(words, corpus=corpus)
#     117
#     118     return word_tags
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/perceptron.py in tag(words, corpus)
#      61     if corpus == "orchid" or corpus == "orchid_ud":
#      62         words = orchid.pre_process(words)
# ---> 63         word_tags = _orchid_tagger().tag(words)
#      64         word_tags = orchid.post_process(word_tags, to_ud)
#      65     elif corpus == "lst20" or corpus == "lst20_ud":
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/_tag_perceptron.py in tag(self, tokens)
#     135         output = []
#     136
# --> 137         context = self.START + [self._normalize(w) for w in tokens] + self.END
#     138         for i, word in enumerate(tokens):
#     139             tag = self.tagdict.get(word)
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/_tag_perceptron.py in <listcomp>(.0)
#     135         output = []
#     136
# --> 137         context = self.START + [self._normalize(w) for w in tokens] + self.END
#     138         for i, word in enumerate(tokens):
#     139             tag = self.tagdict.get(word)
#
# /usr/local/lib/python3.7/dist-packages/pythainlp/tag/_tag_perceptron.py in _normalize(self, word)
#     227         elif word.isdigit() and len(word) == 4:
#     228             return "!YEAR"
# --> 229         elif word[0].isdigit():
#     230             return "!DIGITS"
#     231         else:
#
# IndexError: string index out of range

# %%
docs[0]
